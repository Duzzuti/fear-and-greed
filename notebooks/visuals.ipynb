# %%
main_dir = "../"
data_dir = main_dir + "test_data4/"
sp500_dir = data_dir + "sp500/"
repo_dir = main_dir + "repoData/"

# %%
import sys
sys.path.append(main_dir)
import utils
utils.update_date_count(data_dir, repo_dir)

# %%
# plot date_count.csv
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(main_dir + "date_count.csv")
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)
df.plot()
plt.show()
